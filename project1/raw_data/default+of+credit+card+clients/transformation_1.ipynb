# %%
## Objective is convert the excel format to csv format. Also replace the colum names for teh first line

# %%
import pandas as pd

# %%
dataset = pd.read_excel('default of credit card clients.xls')

# %%
dataset
# Out:
#       Unnamed: 0         X1   X2         X3        X4   X5     X6     X7  \
# 0             ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2
# 1              1      20000    2          2         1   24      2      2
# 2              2     120000    2          2         2   26     -1      2
# 3              3      90000    2          2         2   34      0      0
# 4              4      50000    2          2         1   37      0      0
# ...          ...        ...  ...        ...       ...  ...    ...    ...
# 29996      29996     220000    1          3         1   39      0      0
# 29997      29997     150000    1          3         2   43     -1     -1
# 29998      29998      30000    1          2         2   37      4      3
# 29999      29999      80000    1          3         1   41      1     -1
# 30000      30000      50000    1          2         1   46      0      0
#
#           X8     X9  ...        X15        X16        X17       X18       X19  \
# ...

# %%
dataset['X1']
# Out:
# 0        LIMIT_BAL
# 1            20000
# 2           120000
# 3            90000
# 4            50000
#            ...
# 29996       220000
# 29997       150000
# 29998        30000
# 29999        80000
# 30000        50000
# Name: X1, Length: 30001, dtype: object

# %%
dataset.iloc[0,1]
# Out:
# 'LIMIT_BAL'

# %%
dataset.columns
# Out:
# Index(['Unnamed: 0', 'X1', 'X2', 'X3', 'X4', 'X5', 'X6', 'X7', 'X8', 'X9',
#        'X10', 'X11', 'X12', 'X13', 'X14', 'X15', 'X16', 'X17', 'X18', 'X19',
#        'X20', 'X21', 'X22', 'X23', 'Y'],
#       dtype='object')

# %%
dataset = dataset.drop('Unnamed: 0', axis = 1)
dataset
# Out:
#               X1   X2         X3        X4   X5     X6     X7     X8     X9  \
# 0      LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4
# 1          20000    2          2         1   24      2      2     -1     -1
# 2         120000    2          2         2   26     -1      2      0      0
# 3          90000    2          2         2   34      0      0      0      0
# 4          50000    2          2         1   37      0      0      0      0
# ...          ...  ...        ...       ...  ...    ...    ...    ...    ...
# 29996     220000    1          3         1   39      0      0      0      0
# 29997     150000    1          3         2   43     -1     -1     -1     -1
# 29998      30000    1          2         2   37      4      3      2     -1
# 29999      80000    1          3         1   41      1     -1      0      0
# 30000      50000    1          2         1   46      0      0      0      0
#
# ...

# %%
labels = [f"X{i}" for i in range(1,24)]
labels
# Out:
# ['X1',
#  'X2',
#  'X3',
#  'X4',
#  'X5',
#  'X6',
#  'X7',
#  'X8',
#  'X9',
#  'X10',
#  'X11',
#  'X12',
#  'X13',
#  'X14',
#  'X15',
#  'X16',
#  'X17',
#  'X18',
#  'X19',
#  'X20',
#  'X21',
#  'X22',
#  'X23']

# %%
replacement = [dataset.iloc[0,i] for i in range(0,23) ]
replacement
# Out:
# ['LIMIT_BAL',
#  'SEX',
#  'EDUCATION',
#  'MARRIAGE',
#  'AGE',
#  'PAY_0',
#  'PAY_2',
#  'PAY_3',
#  'PAY_4',
#  'PAY_5',
#  'PAY_6',
#  'BILL_AMT1',
#  'BILL_AMT2',
#  'BILL_AMT3',
#  'BILL_AMT4',
#  'BILL_AMT5',
#  'BILL_AMT6',
#  'PAY_AMT1',
#  'PAY_AMT2',
#  'PAY_AMT3',
#  'PAY_AMT4',
#  'PAY_AMT5',
#  'PAY_AMT6']

# %%
len(replacement)
# Out:
# 23

# %%
columns = dict(zip(labels,replacement))
columns
# Out:
# {'X1': 'LIMIT_BAL',
#  'X2': 'SEX',
#  'X3': 'EDUCATION',
#  'X4': 'MARRIAGE',
#  'X5': 'AGE',
#  'X6': 'PAY_0',
#  'X7': 'PAY_2',
#  'X8': 'PAY_3',
#  'X9': 'PAY_4',
#  'X10': 'PAY_5',
#  'X11': 'PAY_6',
#  'X12': 'BILL_AMT1',
#  'X13': 'BILL_AMT2',
#  'X14': 'BILL_AMT3',
#  'X15': 'BILL_AMT4',
#  'X16': 'BILL_AMT5',
#  'X17': 'BILL_AMT6',
#  'X18': 'PAY_AMT1',
#  'X19': 'PAY_AMT2',
#  'X20': 'PAY_AMT3',
#  'X21': 'PAY_AMT4',
#  'X22': 'PAY_AMT5',
#  'X23': 'PAY_AMT6'}

# %%
dataset = dataset.rename(columns=columns)

# %%
dataset
# Out:
#        LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0      LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4
# 1          20000    2          2         1   24      2      2     -1     -1
# 2         120000    2          2         2   26     -1      2      0      0
# 3          90000    2          2         2   34      0      0      0      0
# 4          50000    2          2         1   37      0      0      0      0
# ...          ...  ...        ...       ...  ...    ...    ...    ...    ...
# 29996     220000    1          3         1   39      0      0      0      0
# 29997     150000    1          3         2   43     -1     -1     -1     -1
# 29998      30000    1          2         2   37      4      3      2     -1
# 29999      80000    1          3         1   41      1     -1      0      0
# 30000      50000    1          2         1   46      0      0      0      0
#
# ...

# %%
df = dataset.drop(0)
df
# Out:
#       LIMIT_BAL SEX EDUCATION MARRIAGE AGE PAY_0 PAY_2 PAY_3 PAY_4 PAY_5  ...  \
# 1         20000   2         2        1  24     2     2    -1    -1    -2  ...
# 2        120000   2         2        2  26    -1     2     0     0     0  ...
# 3         90000   2         2        2  34     0     0     0     0     0  ...
# 4         50000   2         2        1  37     0     0     0     0     0  ...
# 5         50000   1         2        1  57    -1     0    -1     0     0  ...
# ...         ...  ..       ...      ...  ..   ...   ...   ...   ...   ...  ...
# 29996    220000   1         3        1  39     0     0     0     0     0  ...
# 29997    150000   1         3        2  43    -1    -1    -1    -1     0  ...
# 29998     30000   1         2        2  37     4     3     2    -1     0  ...
# 29999     80000   1         3        1  41     1    -1     0     0     0  ...
# 30000     50000   1         2        1  46     0     0     0     0     0  ...
#
# ...

# %%
df.dtypes
# Out:
# LIMIT_BAL    object
# SEX          object
# EDUCATION    object
# MARRIAGE     object
# AGE          object
# PAY_0        object
# PAY_2        object
# PAY_3        object
# PAY_4        object
# PAY_5        object
# PAY_6        object
# BILL_AMT1    object
# BILL_AMT2    object
# BILL_AMT3    object
# BILL_AMT4    object
# BILL_AMT5    object
# BILL_AMT6    object
# PAY_AMT1     object
# PAY_AMT2     object
# PAY_AMT3     object
# PAY_AMT4     object
# PAY_AMT5     object
# PAY_AMT6     object
# Y            object
# dtype: object

# %%
"""
from sklearn.preprocessing import MinMaxScaler
import pandas as pd

# Sample DataFrame
data = {'A': [1, 2, 3], 'B': [4, 5, 6], 'C': ['cat', 'dog', 'mouse'], 'D': [7.5, 8.5, 9.5]}
df = pd.DataFrame(data)

# Specify the columns to normalize
columns_to_normalize = ['A', 'B']

# Initialize the MinMaxScaler
scaler = MinMaxScaler()

# Apply scaler only to the specified columns
df[columns_to_normalize] = scaler.fit_transform(df[columns_to_normalize])

print(df)
"""

# %%
df.to_csv('Default_of_Credit_Card_Clients.csv', index = False)
